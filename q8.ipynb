# %% [markdown]
# <a href="https://colab.research.google.com/github/gnaneshganta/python-record/blob/main/q8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Q71="7.1. Write a python program to implement insertion sort using lists."
print(Q71)
def insertion_sort(arr):
  for i in range(1, len(arr)):
    key = arr[i]
    j = i - 1
    while j >= 0 and arr[j] > key:
      arr[j + 1] = arr[j]
      j -= 1
    arr[j + 1] = key
# Example usage:
nums = [8, 7, 13, 1, -9, 4]
insertion_sort(nums)
print("Insertion sort result:", nums)
# Out:
# 7.1. Write a python program to implement insertion sort using lists.
# Insertion sort result: [-9, 1, 4, 7, 8, 13]
